# %% [markdown]
# # File I/O

# %% [markdown]
# ## Overview
#
# This section covers file I/O functions from NCL:
#
# - [addfile](#addfile)

# %% [markdown]
# ## Functions
#
# ### addfile
# NCL's [`addfile`](https://www.ncl.ucar.edu/Document/Functions/Built-in/addfile.shtml) opens a data file from supported file formats

# %% [markdown]
# #### Grab and Go
#
# - netCDF, HDF5, and HDF-EOS5

# %%
import geocat.datafiles as gcd
import xarray as xr

data_filepath = gcd.get("netcdf_files/1994_256_FSD.nc")
netCDF_datafile = xr.open_dataset(data_filepath)
netCDF_datafile

# %% [markdown]
# #### Grab and Go
#
# - HDF4 and HDF-EOS
#
# `xarray` can support additional file formats with the addition of [specified engines](https://docs.xarray.dev/en/stable/user-guide/io.html#backend-selection)

# %%
import geocat.datafiles as gcd
import xarray as xr

data_filepath = gcd.get("hdf_files/avhrr.hdf")
hdf_datafile = xr.open_dataset(data_filepath, engine="netcdf4")
hdf_datafile

# %% [markdown]
# #### Additional file formats:

# %% [markdown]
# ##### GRIB
# ```{admonition} Important Note
# GRIB files need the additional `cfgrib` engine, which can be installed alongside Xarray:
# ```
# ```
# conda install -c conda-forge cfgrib eccodes
# ```
# ```
# import geocat.datafiles as gcd
# import xarray as xr
#
# grib_datafile = xr.open_dataset(
#     gcd.get("grib_files/ST4.2002030112.06h.grb"), engine="cfgrib"
# )
# grib_datafile
# ```

# %% [markdown]
# ##### Shapefiles
#
# ```{admonition} Important Note
# Shapefiles can be read via the `geopandas` `read_file()` function
# ```
#
# ```
# conda install -c conda-forge geopandas
# ```
#
# Shapefiles require both the `.shp` and index `.shx` file
#
# ```
# import geocat.datafiles as gcd
# import geopandas as gpd
#
# shp_dbffile = gpd.read_file(gcd.get("shape_files/states.dbf"))
# shp_prjfile = gpd.read_file(gcd.get("shape_files/states.prj"))
# shp_idxfile = gpd.read_file(gcd.get("shape_files/states.shx"))
# shp_datafile = gpd.read_file(gcd.get("shape_files/states.shp"))
# ```
# Sometimes, the Shapefile's [associated files types](https://en.wikipedia.org/wiki/Shapefile) are not available. In these instances, if the index file (`.shx`) is missing, it can be repaired with `gdal` by setting `SHAPE_RESTORE_SHX` to `YES` before reading the file
#
# ```
# conda install -c conda-forge gdal
# ```
# Where:
# ```
# import geocat.datafiles as gcd
# import geopandas as gpd
#
# from osgeo import gdal
#
# gdal.SetConfigOption('SHAPE_RESTORE_SHX', 'YES')
#
# shp_datafile = gpd.read_file(gcd.get("shape_files/states.shp"))
# ```

# %% [markdown]
# ## Python Resources
# - [Reading and writing files in Xarray](https://docs.xarray.dev/en/stable/user-guide/io.html)
# - [Xarray optional engines](https://docs.xarray.dev/en/stable/generated/xarray.backends.list_engines.html)
# - [Reading files with GeoPandas](https://geopandas.org/en/stable/docs/reference/api/geopandas.read_file.html)
# - [Rasterio and rioxarray: GDAL readable raster data with Xarray](https://docs.xarray.dev/en/stable/user-guide/io.html#rasterio)
# - [Working with MODIS HDF4 data in Python](https://earthdatascience.org/courses/use-data-open-source-python/hierarchical-data-formats-hdf/open-MODIS-hdf4-files-python/)
# - [Working with ESRI Shapefiles](https://doc.arcgis.com/en/arcgis-online/reference/shapefiles.htm)
